# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("./knn_scores.csv")
plt.plot(df["k"], df["score"])
plt.plot(df["k"], df["sensitivity"], label="sensitivity", color="orange")
plt.plot(df["k"], df["specificity"], label="specificity", color="pink")
plt.legend()

# %%
df["k"]
# Out:
# 0      2
# 1      3
# 2      4
# 3      5
# 4     10
# 5     50
# 6    100
# 7    150
# Name: k, dtype: int64
